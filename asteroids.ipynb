# %%
# %load_ext autoreload
# %autoreload 2
import asteroidgraph

# %%
#only use this cell when initially downloading the data.  not needed after that.
#finalproject.downloadthedata()

# %%
asteroid_table = asteroidgraph.readthedata()

# %%
asteroidgraph.plotthedata(asteroid_table) # non-interactive plot

# %%
asteroidgraph.interactive_asteroid_plot(asteroid_table) # interactive plot
# Out:
# interactive(children=(FloatSlider(value=1.0, description='x1', max=10.0, step=0.05), FloatSlider(value=5.5, de…
